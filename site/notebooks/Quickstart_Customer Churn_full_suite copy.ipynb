# %% [markdown]
# # Quickstart - Customer Churn Full Suite Model Documentation

# %% [markdown]
# This interactive notebook will guide you through documenting a model using the ValidMind Developer framework. We will use sample datasets provided by the library and train a simple classification model.
#
# For this simple demonstration, we will use the following bank customer churn dataset from Kaggle: https://www.kaggle.com/code/kmalit/bank-customer-churn-prediction/data.
#
# We will train a sample model and demonstrate the following documentation functionalities:
#
# - Initializing the ValidMind Developer Framework
# - Using a sample datasets provided by the library to train a simple classification model
# - Running a test suite to quickly generate document about the data and model

# %% [markdown]
# ## Before You Begin
#
# ::: {.callout-tip}
# ## Need a hand?
# First time working with Validmind? Try [reading our quickstart.](../guide/quickstart.qmd)<br>
# Not what you're looking for? Try reaching out to our support team at [support@validmind.com](mailto:support@validmind.com) for further assistance.
# :::

# %% [markdown]
# To set up our Developer Framework, run each of the following code snippets.

# %% [markdown]
# ## Install the Validmind Developer framework

# %%
# %pip install --upgrade validmind
# Out:
# Requirement already satisfied: validmind in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (1.15.5)
# Requirement already satisfied: xgboost<2.0.0,>=1.5.2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.7.6)
# Requirement already satisfied: ipython==7.34.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (7.34.0)
# Requirement already satisfied: arch<6.0.0,>=5.4.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (5.6.0)
# Requirement already satisfied: catboost<2.0,>=1.2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.2)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.10.10)
# Requirement already satisfied: pdoc<14.0.0,>=13.1.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (13.1.1)
# Requirement already satisfied: pandas-profiling<4.0.0,>=3.6.6 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (3.6.6)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (2.31.0)
# Requirement already satisfied: sphinx<7.0.0,>=6.1.3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (6.2.1)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.3.0)
# Requirement already satisfied: sentry-sdk<2.0.0,>=1.24.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.26.0)
# Requirement already satisfied: myst-parser<2.0.0,>=1.0.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.0.0)
# Requirement already satisfied: pypmml<0.10.0,>=0.9.17 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.9.17)
# Requirement already satisfied: aiohttp[speedups]<4.0.0,>=3.8.4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (3.8.4)
# Requirement already satisfied: shap<0.42.0,>=0.41.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.41.0)
# Requirement already satisfied: markdown<4.0.0,>=3.4.3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (3.4.3)
# Requirement already satisfied: numpy==1.22.3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.22.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (4.65.0)
# Requirement already satisfied: dython<0.8.0,>=0.7.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.7.2)
# Requirement already satisfied: pandas==1.5.3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.5.3)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.9 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.8.10)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (3.8.1)
# Requirement already satisfied: click<9.0.0,>=8.0.4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (8.1.3)
# Requirement already satisfied: sphinx-rtd-theme<2.0.0,>=1.2.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (1.2.2)
# Requirement already satisfied: statsmodels<0.14.0,>=0.13.5 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.13.5)
# Requirement already satisfied: kaleido==0.2.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.2.1)
# Requirement already satisfied: plotly<6.0.0,>=5.14.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (5.15.0)
# Requirement already satisfied: python-dotenv<0.21.0,>=0.20.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.20.0)
# Requirement already satisfied: seaborn<0.12.0,>=0.11.2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.11.2)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.0.6 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (8.0.6)
# Requirement already satisfied: sphinx-markdown-builder<0.6.0,>=0.5.5 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from validmind) (0.5.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (3.0.38)
# Requirement already satisfied: setuptools>=18.5 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ipython==7.34.0->validmind) (57.4.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (0.18.2)
# Requirement already satisfied: pygments in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (2.15.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (5.9.0)
# Requirement already satisfied: backcall in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (0.2.0)
# Requirement already satisfied: colorama in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (0.4.6)
# Requirement already satisfied: matplotlib-inline in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (0.1.6)
# Requirement already satisfied: decorator in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipython==7.34.0->validmind) (0.7.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\parri\appdata\roaming\python\python39\site-packages (from pandas==1.5.3->validmind) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from pandas==1.5.3->validmind) (2023.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (3.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (23.1.0)
# Requirement already satisfied: cchardet in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (2.1.7)
# Requirement already satisfied: Brotli in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (1.0.9)
# Requirement already satisfied: aiodns in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (3.0.0)
# Requirement already satisfied: property-cached>=1.6.4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from arch<6.0.0,>=5.4.0->validmind) (1.6.4)
# Requirement already satisfied: scipy>=1.3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from arch<6.0.0,>=5.4.0->validmind) (1.10.1)
# Requirement already satisfied: matplotlib in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from catboost<2.0,>=1.2->validmind) (3.7.1)
# Requirement already satisfied: graphviz in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from catboost<2.0,>=1.2->validmind) (0.20.1)
# Requirement already satisfied: six in c:\users\parri\appdata\roaming\python\python39\site-packages (from catboost<2.0,>=1.2->validmind) (1.16.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from dython<0.8.0,>=0.7.1->validmind) (0.3.7)
# Requirement already satisfied: psutil>=5.9.1 in c:\users\parri\appdata\roaming\python\python39\site-packages (from dython<0.8.0,>=0.7.1->validmind) (5.9.5)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<9.0.0,>=8.0.6->validmind) (4.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipywidgets<9.0.0,>=8.0.6->validmind) (6.23.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<9.0.0,>=8.0.6->validmind) (3.0.7)
# Requirement already satisfied: packaging in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (23.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (0.1.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (6.3.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (8.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (1.5.6)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (1.6.7)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (5.3.1)
# Requirement already satisfied: pyzmq>=20 in c:\users\parri\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\parri\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython==7.34.0->validmind) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\parri\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\parri\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (3.15.0)
# Requirement already satisfied: pywin32>=300 in c:\users\parri\appdata\roaming\python\python39\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (306)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\parri\appdata\roaming\python\python39\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9.0.0,>=8.0.6->validmind) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost<2.0,>=1.2->validmind) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost<2.0,>=1.2->validmind) (4.40.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost<2.0,>=1.2->validmind) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost<2.0,>=1.2->validmind) (3.1.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost<2.0,>=1.2->validmind) (9.5.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost<2.0,>=1.2->validmind) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost<2.0,>=1.2->validmind) (1.4.4)
# Requirement already satisfied: jinja2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from myst-parser<2.0.0,>=1.0.0->validmind) (3.1.2)
# Requirement already satisfied: docutils<0.20,>=0.15 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from myst-parser<2.0.0,>=1.0.0->validmind) (0.18.1)
# Requirement already satisfied: mdit-py-plugins~=0.3.4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from myst-parser<2.0.0,>=1.0.0->validmind) (0.3.5)
# Requirement already satisfied: pyyaml in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from myst-parser<2.0.0,>=1.0.0->validmind) (6.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=1.0.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from myst-parser<2.0.0,>=1.0.0->validmind) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py<3.0.0,>=1.0.0->myst-parser<2.0.0,>=1.0.0->validmind) (0.1.2)
# Requirement already satisfied: joblib in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from nltk<4.0.0,>=3.8.1->validmind) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from nltk<4.0.0,>=3.8.1->validmind) (2023.6.3)
# Requirement already satisfied: ydata-profiling in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from pandas-profiling<4.0.0,>=3.6.6->validmind) (4.3.1)
# Requirement already satisfied: MarkupSafe in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from pdoc<14.0.0,>=13.1.1->validmind) (2.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from plotly<6.0.0,>=5.14.1->validmind) (8.2.2)
# Requirement already satisfied: wcwidth in c:\users\parri\appdata\roaming\python\python39\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.34.0->validmind) (0.2.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\parri\appdata\roaming\python\python39\site-packages (from pydantic<2.0.0,>=1.9.1->validmind) (4.7.0)
# Requirement already satisfied: py4j>=0.10.7 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from pypmml<0.10.0,>=0.9.17->validmind) (0.10.9.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.27.1->validmind) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.27.1->validmind) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.27.1->validmind) (2.0.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn<2.0.0,>=1.0.2->validmind) (3.1.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from shap<0.42.0,>=0.41.0->validmind) (0.0.7)
# Requirement already satisfied: cloudpickle in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from shap<0.42.0,>=0.41.0->validmind) (2.2.1)
# Requirement already satisfied: numba in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from shap<0.42.0,>=0.41.0->validmind) (0.57.1)
# Requirement already satisfied: snowballstemmer>=2.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (2.2.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (1.0.4)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (2.0.1)
# Requirement already satisfied: babel>=2.9 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (2.12.1)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (1.0.1)
# Requirement already satisfied: imagesize>=1.3 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (1.4.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (0.7.13)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (1.0.3)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx<7.0.0,>=6.1.3->validmind) (1.1.5)
# Requirement already satisfied: html2text in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx-markdown-builder<0.6.0,>=0.5.5->validmind) (2020.1.16)
# Requirement already satisfied: pydash in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx-markdown-builder<0.6.0,>=0.5.5->validmind) (7.0.4)
# Requirement already satisfied: yapf in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx-markdown-builder<0.6.0,>=0.5.5->validmind) (0.40.1)
# Requirement already satisfied: unify in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx-markdown-builder<0.6.0,>=0.5.5->validmind) (0.5)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from sphinx-rtd-theme<2.0.0,>=1.2.0->validmind) (4.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from statsmodels<0.14.0,>=0.13.5->validmind) (0.5.3)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from aiodns->aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (4.3.0)
# Requirement already satisfied: cffi>=1.5.0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from pycares>=4.0.0->aiodns->aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->aiohttp[speedups]<4.0.0,>=3.8.4->validmind) (2.21)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from numba->shap<0.42.0,>=0.41.0->validmind) (0.40.1)
# Requirement already satisfied: untokenize in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from unify->sphinx-markdown-builder<0.6.0,>=0.5.5->validmind) (0.1.1)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from yapf->sphinx-markdown-builder<0.6.0,>=0.5.5->validmind) (2.0.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (1.9.2)
# Requirement already satisfied: typeguard<3,>=2.13.2 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (2.13.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (1.8.1)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (0.12.3)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (0.7.5)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (1.9.1)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (0.1.12)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (4.3.1)
# Requirement already satisfied: PyWavelets in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (1.4.1)
# Requirement already satisfied: networkx>=2.4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\parri\appdata\local\programs\python\python39\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling<4.0.0,>=3.6.6->validmind) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\Users\parri\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ::: {.column-margin}
# ::: {.callout-tip}
# Follow this link to read about [installing and initializing](../guide/install-and-initialize-developer-framework.qmd) our Developer Framework in-depth.
# :::
# :::

# %% [markdown]
# ## Initialize the Python environment

# %%
import pandas as pd
import xgboost as xgb

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# ## Initialize the Validmind Client Library

# %% [markdown]
# To link a project with the client library, you will need to find the initialization code in the **Client Integration** page on the appropriate project.
#
# ::: {.callout-tip}
# ## Don't have a documentation project?
# Learn how to [create your first.](../guide/create-documentation-project.qmd).
# :::
#
# Copy and paste it directly into the following cell, and run the cell to initialize the client library:

# %%
## Replace the code below with the code snippet from your project ##

import validmind as vm

vm.init(
  api_host = "https://api.prod.validmind.ai/api/v1/tracking",
  api_key = "246a6c36b1550c66619cf901ce9d9e0f",
  api_secret = "API_SECRET",
  project = "cljj1g5ss03ou18jqw1pnvcqf"
)
# Out:
# 2023-06-30 16:17:09,503 - ERROR - api_client - Failed to connect to ValidMind API: {"code": "invalid_credentials", "description": "Invalid API credentials"}
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32084\1755040148.py in <cell line: 5>()
#       3 import validmind as vm
#       4
# ----> 5 vm.init(
#       6   api_host = "https://api.prod.validmind.ai/api/v1/tracking",
#       7   api_key = "246a6c36b1550c66619cf901ce9d9e0f",
#
# c:\Users\parri\AppData\Local\Programs\Python\Python39\lib\site-packages\validmind\api_client.py in init(project, api_key, api_secret, api_host)
#     115         if _api_host.startswith("https://"):
#     116             send_single_error(e)
# --> 117         raise e
#     118
#     119
#
# c:\Users\parri\AppData\Local\Programs\Python\Python39\lib\site-packages\validmind\api_client.py in init(project, api_key, api_secret, api_host)
#     110
#     111     try:
# --> 112         __ping()
#     113     except Exception as e:
#     114         # if the api host is https, assume we're not in dev mode and send to sentry
#
# c:\Users\parri\AppData\Local\Programs\Python\Python39\lib\site-packages\validmind\api_client.py in __ping()
#     147     if r.status_code != 200:
#     148         logger.error(f"Failed to connect to ValidMind API: {r.text}")
# --> 149         raise ConnectionError(r.text)
#     150
#     151     client_info = r.json()
#
# ConnectionError: {"code": "invalid_credentials", "description": "Invalid API credentials"}

# %% [markdown]
# ## Load the Demo Dataset

# %% [markdown]
# For the purpose of this demonstration, we will use a sample dataset provided by the ValidMind library.

# %%
# Import the sample dataset from the library
from validmind.datasets.classification import customer_churn as demo_dataset
# You can try a different dataset with: 
#from validmind.datasets.classification import taiwan_credit as demo_dataset

df = demo_dataset.load_data()

# %% [markdown]
# #### Initialize a dataset object for ValidMind
#
# Before running the test plan, we must first initialize a ValidMind dataset object using the `init_dataset` function from the `vm` module. This function takes in arguements: `dataset` which is the dataset that we want to analyze; `target_column` which is used to identify the target variable; `class_labels` which is used to identify the labels used for classification model training.

# %%
vm_dataset = vm.init_dataset(
    dataset=df,
    target_column=demo_dataset.target_column,
    class_labels=demo_dataset.class_labels
)

# %% [markdown]
# ## Run the Full Data and Model Validation Test Suite

# %% [markdown]
# We will need to preprocess the dataset and produce the training, test and validation splits first.

# %% [markdown]
# ### Prepocess the Raw Dataset

# %% [markdown]
# For demonstration purposes, we simplified the preprocessing using demo_dataset.preprocess which executes the following operations:

# %%
train_df, validation_df, test_df = demo_dataset.preprocess(df)

x_train = train_df.drop(demo_dataset.target_column, axis=1)
y_train = train_df[demo_dataset.target_column]
x_val = validation_df.drop(demo_dataset.target_column, axis=1)
y_val = validation_df[demo_dataset.target_column]

model = xgb.XGBClassifier(early_stopping_rounds=10)
model.set_params(
    eval_metric=["error", "logloss", "auc"],
)
model.fit(
    x_train,
    y_train,
    eval_set=[(x_val, y_val)],
    verbose=False,
)

# %% [markdown]
# We can now initialize the training and test datasets into dataset objects using vm.init_dataset():

# %%
vm_train_ds = vm.init_dataset(
    dataset=train_df,
    type="generic",
    target_column=demo_dataset.target_column
)

vm_test_ds = vm.init_dataset(
    dataset=test_df,
    type="generic",
    target_column=demo_dataset.target_column
)

# %% [markdown]
# We also initialize a model object using vm.init_model():

# %%
vm_model = vm.init_model(
    model,
    train_ds=vm_train_ds,
    test_ds=vm_test_ds,
)

# %% [markdown]
# ### Run the Full Suite

# %% [markdown]
# We are now ready to run the test suite for binary classifier with tabular datasets. This function will run test plans on the dataset and model objects, and will document the results in the ValidMind UI.

# %%
full_suite = vm.run_test_suite(
    "binary_classifier_full_suite",
    dataset=vm_dataset,
    model=vm_model
)

# %%
vm.test_plans.list_tests()

# %%
vm.test_plans.describe_plan("tabular_data_quality")

# %%
full_suite = vm.run_test_suite(
    "binary_classifier_full_suite",
    dataset=vm_dataset,
    model=vm_model
)

# %% [markdown]
# You can access and review the resulting documentation in the ValidMind UI, in the "Model Development" section of the model documentation.
