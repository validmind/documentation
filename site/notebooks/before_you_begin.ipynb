# %% [markdown]
# ## Before You Begin
#
# ::: {.callout-tip}
# ## Need a hand?
# First time working with Validmind? Try [reading our quickstart.](../guide/quickstart.qmd)<br>
# Not what you're looking for? Try reaching out to our support team at [support@validmind.com](mailto:support@validmind.com) for further assistance.
# :::

# %% [markdown]
# ## Set up the Developer Framework

# %% [markdown]
# Follow these links to [install and initialize](../guide/install-and-initialize-developer-framework.qmd) our Developer Framework, and [create your first documentation project.](../guide/create-documentation-project.qmd)

# %% [markdown]
# ## Initialize the Python environment

# %% [markdown]
# To initialize the Python environment, run the following code snippet:

# %%
import pandas as pd
import xgboost as xgb

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %matplotlib inline
